# %% [markdown]
# <a href="https://colab.research.google.com/github/Akashrathor4/python_language/blob/main/pythonlesson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a_number = 34

# %%
if a_number%2 == 0:
  print("we are inside an if block")
  print("the given number {} is even.".format(a_number))
# Out:
# we are inside an if block
# the given number 34 is even.

# %%
another_number = 33

# %%
if another_number % 2 == 0:
  print("The given number {} is even.".format(another_number))

# %%
if a_number % 2 == 0:
  print("the given number {} is even.".format(a_number))
else:
  print("The given number {} is odd.".format(a_number))
# Out:
# the given number 34 is even.

# %%
another_number
# Out:
# 33

# %%
if another_number % 2 == 0:
  print("the given number {} is even.".format(another_number))
else:
  print("The given number {} is odd.".format(another_number))
# Out:
# The given number 33 is odd.

# %%
the_3_musketeers = ("Athos", "Porthos", "Aramis")

# %%
a_candidate = "d'artagnan"

# %%
if a_candidate in the_3_musketeers:
  print("{} is a musketeer".format(a_candidate))
else:
  print("{} is not a musketeer".format(a_candidate))
# Out:
# d'artagnan is not a musketeer

# %%
signal = "green"

# %%
if signal == "red":
  print("stop")
elif signal == "yellow":
  print("be ready")
else:
  print("go")
# Out:
# go

# %%
a_number = 12

# %%
if a_number % 3 == 0 and a_number % 5 ==0:
  print("The number {} is divisible by 3 and 5".format(a_number))
elif not a_number % 5 == 0:
  print('the number {} is not divisible by 5'.format(a_number))
# Out:
# the number 12 is not divisible by 5

# %%
if "":
  print("the condition evaluated to True")
else:
  print("the condition evaluated to False")
# Out:
# the condition evaluated to False

# %%
if "hello":
  print("the condition evaluated to True")
else:
  print("the condition evaluated to False")
# Out:
# the condition evaluated to True

# %%
if {"a":12}:
  print("the condition evaluated to True")
else:
  print("the condition evaluated to False")
# Out:
# the condition evaluated to True

# %%
if None:
  print("the condition evaluated to True")
else:
  print("the condition evaluated to False")
# Out:
# the condition evaluated to False

# %%
a_number = 15

# %%
if a_number % 2 == 0:
  print("{} is also divisible by 3.".format(a_number))
  if a_number % 3 == 0:
    print("{} is also divisible by 3".format(a_number))
  else:
    print("{} is not diviisible by 3.".format(a_number))
else:
  print("{} is odd".format(a_number))
  if a_number % 5 == 0:
    print("{} is also divisible by 5 ".format(a_number))
  else:
    print("{} is not divisible by 5 ".format(a_number))
# Out:
# 15 is odd
# 15 is also divisible by 5

# %%
a_number = 13

if a_number % 2 == 0:
  parity = "even"
else:
  parity = "odd"

print("the number {} is {}.".format(a_number,parity))
# Out:
# the number 13 is odd.

# %%
parity = 'even' if a_number % 2 == 0 else "odd"

# %%
print("the number {} is {}.".format(a_number,parity))
# Out:
# the number 13 is odd.

# %%
a_number = 15
if a_number % 2 == 0 :
  pass
elif a_number % 3 == 0:
  print("{} is divisible by 3 but not divisible by 2".format(a_number))
# Out:
# 15 is divisible by 3 but not divisible by 2

# %%
# %%time
result =  1;
i =1;
while i<=100:
  result *= i
  i = i+1

print("the factorial of 100 is :{}".format(result))
# Out:
# the factorial of 100 is :93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000
# CPU times: user 115 µs, sys: 9 µs, total: 124 µs
# Wall time: 129 µs

# %%
# %%time
result =  1;
i =1;
while i<=1000:
  result *= i
  i = i+1

print("the factorial of 100 is :{}".format(result))
# Out:
# the factorial of 100 is :...
# CPU times: user 0 ns, sys: 683 µs, total: 683 µs
# Wall time: 690 µs

# %%
line = "*"
max_length = 10

while len(line) <= max_length:
  print(line)
  line += "*"

while len(line)>0:
  print(line)
  line = line[:-1]
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
n = 6

for i in range(1,n+1):
  print(" "*(n-i)+"*"*i)

for i in range(n+1,0,-1):
  print(' '*(n-i)+"*"*i)
# Out:
#      *
#     **
#    ***
#   ****
#  *****
# ******
# *******
# ******
#  *****
#   ****
#    ***
#     **
#      *

# %%
i = 1
result = 1
while i<=100:
  result *= i
  if i == 42:
    print("magic number 42 reached stopping execution..")
    break
  i +=1

print("i:",i)
print("result:",result)
# Out:
# magic number 42 reached stopping execution..
# i: 42
# result: 1405006117752879898543142606244511569936384000000000

# %%
days = ["monday","tuesday","wednesday","thursday","friday"]
for day in days:
  print(day)
# Out:
# monday
# tuesday
# wednesday
# thursday
# friday

# %%
for char in "monday":
  print(char)
# Out:
# m
# o
# n
# d
# a
# y

# %%
for fruit in ("apple","banana",'guava'):
  print("here is a fruit:",fruit)
# Out:
# here is a fruit: apple
# here is a fruit: banana
# here is a fruit: guava

# %%
person = {
    "name":"john doe",
    "sex":"male",
    "age":32,
    "married":True
}

for key in person:
  print("key:",key,":","value:",person[key])
# Out:
# key: name : value: john doe
# key: sex : value: male
# key: age : value: 32
# key: married : value: True

# %%
for value in person.values():
  print(value)
# Out:
# john doe
# male
# 32
# True

# %%
for key_value_pair in person.items():
  print(key_value_pair)
# Out:
# ('name', 'john doe')
# ('sex', 'male')
# ('age', 32)
# ('married', True)

# %%
for key,value in person.items():
  print("key:",key,":","value:",value)
# Out:
# key: name : value: john doe
# key: sex : value: male
# key: age : value: 32
# key: married : value: True

# %%
for i in range(7):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(3,10):
  print(i)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(3,14,4):
  print(i)
# Out:
# 3
# 7
# 11

# %%
days
# Out:
# ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']

# %%
for i in range(len(days)):
  print("the value at position {} is {}.".format(i,days[i]))
# Out:
# the value at position 0 is monday.
# the value at position 1 is tuesday.
# the value at position 2 is wednesday.
# the value at position 3 is thursday.
# the value at position 4 is friday.

# %%
for i,val in enumerate(days):
  print("the value at position {} is {}.".format(i,val))
#
# Out:
# the value at position 0 is monday.
# the value at position 1 is tuesday.
# the value at position 2 is wednesday.
# the value at position 3 is thursday.
# the value at position 4 is friday.

# %%
for day in days:
  pass

# %%
persons = [{'name': 'John', 'sex': 'Male'}, {'name': 'Jane', 'sex': 'Female'}]

# %%
for person in persons:
  for key in person:
    print(key,";",person[key])
  print('')
# Out:
# name ; John
# sex ; Male
#
# name ; Jane
# sex ; Female

# %%
days
# Out:
# ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']

# %%
fruits = ['apple', 'banana', 'guava']

# %%
for day in days:
  for fruit in fruits:
    print(day,fruit)
# Out:
# monday apple
# monday banana
# monday guava
# tuesday apple
# tuesday banana
# tuesday guava
# wednesday apple
# wednesday banana
# wednesday guava
# thursday apple
# thursday banana
# thursday guava
# friday apple
# friday banana
# friday guava

# %%
today = "thursday"

# %%
print("today is",today)
# Out:
# today is thursday

# %%
def say_hello():
  print("hello there!")
  print("how are you?")

say_hello()
# Out:
# hello there!
# how are you?

# %%
def filter_even(number_list):
  result_list=[]
  for number in number_list:
    if number % 2 == 0:
      result_list.append(number)
  return result_list

# %%
even_list=filter_even([1,2,3,4,5,6,7])

# %%
even_list
# Out:
# [2, 4, 6]

# %%
def loan_emi(amount):
  emi = amount / 12
  print("the emi is ${}".format(emi))

# %%
loan_emi(1260000)
# Out:
# the emi is $105000.0

# %%
def loan_emi(amount,duration):
  emi = amount / duration
  print("the emi is ${}".format(emi))

# %%
loan_emi(1260000,8*12)
# Out:
# the emi is $13125.0

# %%
loan_emi(1260000,10*12)
# Out:
# the emi is $10500.0

# %%
def loan_emi(amount,duration):
  emi = amount / duration
  return emi

# %%
emi1 = loan_emi(1260000,8*12)
emi2 = loan_emi(1260000,10*12)

# %%
emi1
emi2
# Out:
# 10500.0

# %%
emi1
# Out:
# 13125.0

# %%
emi2
# Out:
# 10500.0

# %%
def loan_emi(amount,duration,down_payment=0):
  loan_amount = amount - down_payment
  emi = loan_amount / duration
  return emi

# %%
emi1 = loan_emi(1260000,8*12,3e5)
emi2 = loan_emi(1260000,10*12)

# %%
emi1
# Out:
# 10000.0

# %%
emi2
# Out:
# 10500.0

# %%
def loan_emi(amount,duration,rate,down_payment=0):
  loan_amount = amount - down_payment
  emi = loan_amount * rate * ((1+rate)**duration)/(((1+rate)**duration)-1)
  return emi

# %%
loan_emi(1260000,8*12,0.1/12,3e5)
# Out:
# 14567.19753389219

# %%
loan_emi(1260000,10*12,0.08/12)
# Out:
# 15287.276888775077

# %%
import math

# %%
help(math.ceil)
# Out:
# Help on built-in function ceil in module math:
#
# ceil(x, /)
#     Return the ceiling of x as an Integral.
#
#     This is the smallest integer >= x.

# %%
math.ceil(1.2)
# Out:
# 2

# %%
def loan_emi(amount,duration,rate,down_payment=0):
  loan_amount = amount - down_payment
  emi = loan_amount * rate * ((1+rate)**duration)/(((1+rate)**duration)-1)
  emi = math.ceil(emi)
  return emi

# %%
emi1 = loan_emi(
    amount=1260000,
    duration=8*12,
    rate=0.1/12,
    down_payment=3e5
)

# %%
emi1
# Out:
# 14568

# %%
emi2 = loan_emi(amount=1260000, duration=10*12, rate=0.08/12)

# %%
emi2
# Out:
# 15288

# %%
if emi1 < emi2:
  print("option 1 has the lower emi: ${}".format(emi1))
else:
  print("option 2 has the lower emi : ${}".format(emi2))
# Out:
# option 1 has the lower emi: $14568

# %%
def loan_emi(amount, duration, rate, down_payment=0):
    loan_amount = amount - down_payment
    try:
        emi = loan_amount * rate * ((1+rate)**duration) / (((1+rate)**duration)-1)
    except ZeroDivisionError:
        emi = loan_amount / duration
    emi = math.ceil(emi)
    return emi

# %%
emi_with_interest = loan_emi(amount=100000, duration=10*12, rate=0.09/12)

# %%
emi_with_interest
# Out:
# 1267

# %%
emi_without_interest = loan_emi(amount=100000, duration=10*12, rate=0)
emi_without_interest
# Out:
# 834

# %%
total_interest = (emi_with_interest - emi_without_interest) * 10*12

# %%
print("The total interest paid is ${}.".format(total_interest))
# Out:
# The total interest paid is $51960.

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
help(os.listdir)
# Out:
# Help on built-in function listdir in module posix:
#
# listdir(path=None)
#     Return a list containing the names of the files in the directory.
#
#     path can be specified as either str, bytes, or a path-like object.  If path is bytes,
#       the filenames returned will also be bytes; in all other circumstances
#       the filenames returned will be str.
#     If path is None, uses the path='.'.
#     On some platforms, path may also be specified as an open file descriptor;\
#       the file descriptor must refer to a directory.
#       If this functionality is unavailable, using it raises NotImplementedError.
#
#     The list is in arbitrary order.  It does not include the special
#     entries '.' and '..' even if they are present in the directory.

# %%
os.listdir('.')
# Out:
# ['.config', 'sample_data']

# %%
os.listdir('/usr')
# Out:
# ['include',
#  'bin',
#  'share',
#  'lib32',
#  'local',
#  'sbin',
#  'libx32',
#  'lib',
#  'src',
#  'libexec',
#  'games',
#  'lib64',
#  'colab',
#  'etc',
#  'grte']

# %%
os.listdir('.')
# Out:
# ['.config', 'sample_data']

# %%
os.listdir("/")
# Out:
# ['bin',
#  'lib32',
#  'proc',
#  'home',
#  'mnt',
#  'usr',
#  'sbin',
#  'libx32',
#  'lib',
#  'media',
#  'var',
#  'srv',
#  'root',
#  'tmp',
#  'run',
#  'boot',
#  'sys',
#  'lib64',
#  'etc',
#  'opt',
#  'dev',
#  'kaggle',
#  '.dockerenv',
#  'tools',
#  'datalab',
#  'content',
#  'python-apt',
#  'python-apt.tar.xz']

# %%
os.listdir("/content")
# Out:
# ['.config', 'sample_data']

# %%
os.listdir("/content/sample_data")
# Out:
# ['anscombe.json',
#  'README.md',
#  'mnist_train_small.csv',
#  'california_housing_train.csv',
#  'california_housing_test.csv',
#  'mnist_test.csv']

# %%
os.listdir("/content/.config")
# Out:
# ['active_config',
#  'hidden_gcloud_config_universe_descriptor_data_cache_configs.db',
#  '.last_survey_prompt.yaml',
#  'default_configs.db',
#  'gce',
#  '.last_update_check.json',
#  '.last_opt_in_prompt.yaml',
#  'logs',
#  'configurations',
#  'config_sentinel']

# %%
os.listdir(".")
# Out:
# ['.config', 'sample_data']

# %%
os.listdir("/")
# Out:
# ['bin',
#  'lib32',
#  'proc',
#  'home',
#  'mnt',
#  'usr',
#  'sbin',
#  'libx32',
#  'lib',
#  'media',
#  'var',
#  'srv',
#  'root',
#  'tmp',
#  'run',
#  'boot',
#  'sys',
#  'lib64',
#  'etc',
#  'opt',
#  'dev',
#  'kaggle',
#  '.dockerenv',
#  'tools',
#  'datalab',
#  'content',
#  'python-apt',
#  'python-apt.tar.xz']

# %%
os.listdir("/usr")
# Out:
# ['include',
#  'bin',
#  'share',
#  'lib32',
#  'local',
#  'sbin',
#  'libx32',
#  'lib',
#  'src',
#  'libexec',
#  'games',
#  'lib64',
#  'colab',
#  'etc',
#  'grte']

# %%
os.makedirs("./data",exist_ok=True)

# %%
help(os.makedirs)
# Out:
# Help on function makedirs in module os:
#
# makedirs(name, mode=511, exist_ok=False)
#     makedirs(name [, mode=0o777][, exist_ok=False])
#
#     Super-mkdir; create a leaf directory and all intermediate ones.  Works like
#     mkdir, except that any intermediate path segment (not just the rightmost)
#     will be created if it does not exist. If the target directory already
#     exists, raise an OSError if exist_ok is False. Otherwise no exception is
#     raised.  This is recursive.

# %%
'data' in os.listdir('.')
# Out:
# True

# %%
'data' in os.listdir('/content')
# Out:
# True

# %%
"data" in os.listdir("/")
# Out:
# False

# %%
os.listdir("./data")
# Out:
# []

# %%
os.listdir("/content/data")
# Out:
# []

# %%
import urllib.request

# %%
url1 = "https://drive.google.com/uc?id=1zO8ekHWx9U7mrbx_0Hoxxu6od7uxJqWw&export=download"

urllib.request.urlretrieve(url1,"./data/customer.txt")
# Out:
# ('./data/customer.txt', <http.client.HTTPMessage at 0x7b44f65aa1b0>)

# %%
os.listdir('./data')
# Out:
# ['customer.txt']

# %%
file1 = open("./data/customer.txt", mode = "r")

# %%
file_content = file1.read()

# %%
print(file_content)
# Out:
# Index,Customer Id,First Name,Last Name,Company,City,Country,Phone 1,Phone 2,Email,Subscription Date,Website
# 1,DD37Cf93aecA6Dc,Sheryl,Baxter,Rasmussen Group,East Leonard,Chile,229.077.5154,397.884.0519x718,zunigavanessa@smith.info,2020-08-24,http://www.stephenson.com/
# 2,1Ef7b82A4CAAD10,Preston,Lozano,Vega-Gentry,East Jimmychester,Djibouti,5153435776,686-620-1820x944,vmata@colon.com,2021-04-23,http://www.hobbs.com/
# 3,6F94879bDAfE5a6,Roy,Berry,Murillo-Perry,Isabelborough,Antigua and Barbuda,+1-539-402-0259,(496)978-3969x58947,beckycarr@hogan.com,2020-03-25,http://www.lawrence.com/
# 4,5Cef8BFA16c5e3c,Linda,Olsen,"Dominguez, Mcmillan and Donovan",Bensonview,Dominican Republic,001-808-617-6467x12895,+1-813-324-8756,stanleyblackwell@benson.org,2020-06-02,http://www.good-lyons.com/
# ...

# %%
file1.close()

# %%
file1.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-391184240.py in <cell line: 0>()
# ----> 1 file1.read()
#
# ValueError: I/O operation on closed file.

# %%
with open("./data/customer.txt") as file1:
  file_content = file1.read()
  print(file_content)
# Out:
# Index,Customer Id,First Name,Last Name,Company,City,Country,Phone 1,Phone 2,Email,Subscription Date,Website
# 1,DD37Cf93aecA6Dc,Sheryl,Baxter,Rasmussen Group,East Leonard,Chile,229.077.5154,397.884.0519x718,zunigavanessa@smith.info,2020-08-24,http://www.stephenson.com/
# 2,1Ef7b82A4CAAD10,Preston,Lozano,Vega-Gentry,East Jimmychester,Djibouti,5153435776,686-620-1820x944,vmata@colon.com,2021-04-23,http://www.hobbs.com/
# 3,6F94879bDAfE5a6,Roy,Berry,Murillo-Perry,Isabelborough,Antigua and Barbuda,+1-539-402-0259,(496)978-3969x58947,beckycarr@hogan.com,2020-03-25,http://www.lawrence.com/
# 4,5Cef8BFA16c5e3c,Linda,Olsen,"Dominguez, Mcmillan and Donovan",Bensonview,Dominican Republic,001-808-617-6467x12895,+1-813-324-8756,stanleyblackwell@benson.org,2020-06-02,http://www.good-lyons.com/
# ...

# %%
file1.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-391184240.py in <cell line: 0>()
# ----> 1 file1.read()
#
# ValueError: I/O operation on closed file.

# %%
with open("./data/customer.txt",mode="r") as file1:
  file_content = file1.readlines()
  print(file_content)
# Out:
# ['Index,Customer Id,First Name,Last Name,Company,City,Country,Phone 1,Phone 2,Email,Subscription Date,Website\n', '1,DD37Cf93aecA6Dc,Sheryl,Baxter,Rasmussen Group,East Leonard,Chile,229.077.5154,397.884.0519x718,zunigavanessa@smith.info,2020-08-24,http://www.stephenson.com/\n', '2,1Ef7b82A4CAAD10,Preston,Lozano,Vega-Gentry,East Jimmychester,Djibouti,5153435776,686-620-1820x944,vmata@colon.com,2021-04-23,http://www.hobbs.com/\n', '3,6F94879bDAfE5a6,Roy,Berry,Murillo-Perry,Isabelborough,Antigua and Barbuda,+1-539-402-0259,(496)978-3969x58947,beckycarr@hogan.com,2020-03-25,http://www.lawrence.com/\n', '4,5Cef8BFA16c5e3c,Linda,Olsen,"Dominguez, Mcmillan and Donovan",Bensonview,Dominican Republic,001-808-617-6467x12895,+1-813-324-8756,stanleyblackwell@benson.org,2020-06-02,http://www.good-lyons.com/\n', '5,053d585Ab6b3159,Joanna,Bender,"Martin, Lang and Andrade",West Priscilla,Slovakia (Slovak Republic),001-234-203-0635x76146,001-199-446-3860x3486,colinalvarado@miles.net,2021-04-17,https:
# ...

# %%
file_content[0]
type(file_content)
# Out:
# list

# %%
def parse_headers(header_line):
  return header_line.strip().split(',')

# %%
header = parse_headers(file_content[0])

# %%
header
# Out:
# ['Index',
#  'Customer Id',
#  'First Name',
#  'Last Name',
#  'Company',
#  'City',
#  'Country',
#  'Phone 1',
#  'Phone 2',
#  'Email',
#  'Subscription Date',
#  'Website']

# %%
def parse_values(data_line):
  values = []
  for item in data_line.strip().split(','):
    if item == '':
      values.append(0.0)
    else:
      values.append(float(item))

  return values

# %%
parse_values(file_content[5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-717234532.py in <cell line: 0>()
# ----> 1 parse_values(file_content[5])
#
# /tmp/ipython-input-3182439217.py in parse_values(data_line)
#       5       values.append(0.0)
#       6     else:
# ----> 7       values.append(float(item))
#       8
#       9   return values
#
# ValueError: could not convert string to float: '053d585Ab6b3159'

# %%
file_content[1]
# Out:
# '1,DD37Cf93aecA6Dc,Sheryl,Baxter,Rasmussen Group,East Leonard,Chile,229.077.5154,397.884.0519x718,zunigavanessa@smith.info,2020-08-24,http://www.stephenson.com/\n'

# %%
def create_item_dict(values,headers):
  result = {}
  for value,header in zip(values,headers):
    result[header] = value
  return result

# %%
for item in zip([1,2,3],['a','b','c']):
  print(item)
# Out:
# (1, 'a')
# (2, 'b')
# (3, 'c')

# %%
values1 = parse_values(file_content[5])
create_item_dict(values1,header)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4270288840.py in <cell line: 0>()
# ----> 1 values1 = parse_values(file_content[5])
#       2 create_item_dict(values1,header)
#
# /tmp/ipython-input-3182439217.py in parse_values(data_line)
#       5       values.append(0.0)
#       6     else:
# ----> 7       values.append(float(item))
#       8
#       9   return values
#
# ValueError: could not convert string to float: '053d585Ab6b3159'
