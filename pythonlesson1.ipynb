# %% [markdown]
# <a href="https://colab.research.google.com/github/Akashrathor4/python_language/blob/main/pythonlesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
99-77
# Out:
# 22

# %%
3+2+8+9
# Out:
# 22

# %%
23.54* -1432
# Out:
# -33709.28

# %%
100/7
# Out:
# 14.285714285714286

# %%
100//7
# Out:
# 14

# %%
100%7
# Out:
# 2

# %%
5**3
# Out:
# 125

# %%
5.28**2
# Out:
# 27.878400000000003

# %%
((2+5)*(17-3))/(4**3)
# Out:
# 1.53125

# %%
198568-45312-35678
# Out:
# 117578

# %%
2425*24
# Out:
# 58200

# %%
5000-2265-2150
# Out:
# 585

# %%
95844/21
# Out:
# 4564.0

# %%
A_bag_of_ice = 1.25
Profit_margin = .2
total_profit_on_each_bag = A_bag_of_ice*  Profit_margin
No_of_bags = 500
total_Profit = No_of_bags*total_profit_on_each_bag
print(total_Profit)
# Out:
# 125.0

# %%
print("Kahani liko jubani kro :",total_Profit,"likho")
# Out:
# Kahani liko jubani kro : 125.0 likho

# %%
# Akash Rathor
x = 4
print(x)
# Out:
# 4

# %%
"""
Akash
Rathor
"""
a_neutral_number = 2

# %%
a_neutral_number
# Out:
# 2

# %%
Akashmantri = True

# %%
my_favourite_number = 1
my_least_favourite_number = 5
a_neutral_number = 3

# %%
my_favourite_number == 1
# Out:
# True

# %%
my_favourite_number == my_least_favourite_number
# Out:
# False

# %%
my_favourite_number != a_neutral_number
# Out:
# True

# %%
a_neutral_number != 3
# Out:
# False

# %%
my_favourite_number
# Out:
# 1

# %%
my_favourite_number > 0 and my_favourite_number <= 3
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
my_favourite_color = "blue"

# %%
my_favourite_color
# Out:
# 'blue'

# %%
color1,color2,color3 = "blue","green","red"

# %%
color1
# Out:
# 'blue'

# %%
color2
# Out:
# 'green'

# %%
color3
# Out:
# 'red'

# %%
color4 = color5 = color6 = "orange"

# %%
color4
# Out:
# 'orange'

# %%
color5
# Out:
# 'orange'

# %%
a variable = 3
# Out:
#   File "/tmp/ipython-input-1825008678.py", line 1
#     a variable = 3
#       ^
# SyntaxError: invalid syntax

# %%
is_today_$aturday = False

# %%
currYear = 2026

# %%
currYear

# %%
type(currYear)

# %%
pi = 3.141592653589793238

# %%
pi

# %%
type(pi)

# %%
a_number = 3.0

# %%
a_number
# Out:
# 3.0

# %%
type(a_number)
# Out:
# float

# %%
1e-2
# Out:
# 0.01

# %%
1e+2
# Out:
# 100.0

# %%
1e2
# Out:
# 100.0

# %%
float(currYear)
# Out:
# 2026.0

# %%
int(pi)
# Out:
# 3

# %%
type(45*3.0)
# Out:
# float

# %%
5+False
# Out:
# 5

# %%
5+True
# Out:
# 6

# %%
bool(True),bool(1),bool(4.5)
# Out:
# (True, True, True)

# %%
nothing

# %%
nothing = None

# %%
today = "Saturday"

# %%
today
# Out:
# 'Saturday'

# %%
type(today)
# Out:
# str

# %%
my_favourite_movie = "One Flew over the Cuckoo's Nest"

# %%
my_favourite_movie
# Out:
# "One Flew over the Cuckoo's Nest"

# %%
len(my_favourite_movie)
# Out:
# 31

# %%
multiline_string = """a
b"""

# %%
multiline_string
# Out:
# 'a\nb'

# %%
print()

# %%
print(multiline_string)
# Out:
# a
# b

# %%
list(multiline_string)
# Out:
# ['a', '\n', 'b']

# %%
today
# Out:
# 'Saturday'

# %%
today[1]
# Out:
# 'a'

# %%
today[3]
# Out:
# 'u'

# %%
today[5]
# Out:
# 'd'

# %%
today[2:5]
# Out:
# 'tur'

# %%
"day" in today
# Out:
# True

# %%
"Sun" in today
# Out:
# False

# %%
Full_Name = "Sunil Gavaskar"

# %%
greeting = 'Hello'

# %%
greeting + " " + Full_Name + "!"
# Out:
# 'Hello Sunil Gavaskar!'

# %%
today.capitalize()
# Out:
# 'Saturday'

# %%
my_favourite_movie.capitalize()
# Out:
# "One flew over the cuckoo's nest"

# %%
"saturday".upper()
# Out:
# 'SATURDAY'

# %%
another_day =  today.replace("Satur","Wednes")

# %%
another_day
# Out:
# 'Wednesday'

# %%
today
# Out:
# 'Saturday'

# %%
"akash rathor".split(" ")
# Out:
# ['akash', 'rathor']

# %%
a_long_line = "       This is a long line with some space before, after,     and some space in the middle..    "

# %%
a_long_line.strip()
# Out:
# 'This is a long line with some space before, after,     and some space in the middle..'

# %%
akash + 25 + rathor
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-510453998.py in <cell line: 0>()
# ----> 1 akash + 25 + rathor
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
"akash" + 25 + "rathor"

# %%
"akash "+"25"+" rathor"

# %%
str(23.45)

# %%
str(True)

# %%
first_name = "John"

# %%
first_name == "Doe"

# %%
first_name == "john"

# %%
fruit_price = [25,89,36]

# %%
fruit_price

# %%
fruit = ['apple','banana','cherry']

# %%
fruit

# %%
type(fruit)

# %%
a_lit = [23,'hello',None,3.14,fruit,fruit_price]

# %%
a_lit

# %%
len(a_lit)

# %%
empty_list = []

# %%
len(empty_list)

# %%
fruit[0]

# %%
fruit[1]

# %%
fruit[2]

# %%
fruit[4]

# %%
fruit[-1]

# %%
fruit[-2]

# %%
fruit[-5]

# %%
a_list

# %%
a_lit

# %%
a_lit[2:5]

# %%
a_lit[2:10]

# %%
fruit[1] = "blueberry"

# %%
fruit

# %%
fruit.append('dates')

# %%
fruit

# %%
fruit.insert(1,"mangoes")

# %%
fruit

# %%
fruit.remove('datesj')

# %%
fruit.remove("datesJ")

# %%
fruit
# Out:
# ['blueberry', 'mangoes']

# %%
fruit.append(apple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-44237441.py in <cell line: 0>()
# ----> 1 fruit.append(apple)
#
# NameError: name 'apple' is not defined

# %%
fruit.append("apple")

# %%
fruit

# %%
fruit

# %%
fruit.remove("apple")

# %%
fruit

# %%
fruit.pop(2)

# %%
fruit
# Out:
# ['blueberry', 'mangoes']

# %%
fruit.pop()
# Out:
# 'mangoes'

# %%
fruit
# Out:
# ['blueberry']

# %%
"cherry" in fruit
# Out:
# False

# %%
"apple" in fruit
# Out:
# False

# %%
more_fruit = fruit + ['pineapple','papaya','jackfruit']

# %%
more_fruit
# Out:
# ['blueberry', 'pineapple', 'papaya', 'jackfruit']

# %%
more_fruit_copy = more_fruit.copy()

# %%
fruit.reverse()

# %%
fruit
# Out:
# ['blueberry']

# %%
fruit.sort()

# %%
fruit
# Out:
# ['blueberry']

# %%
fruit_price.sort().reverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1988378731.py in <cell line: 0>()
# ----> 1 fruit_price.sort().reverse()
#
# AttributeError: 'NoneType' object has no attribute 'reverse'

# %%
fruit_price.sort(reverse=True)

# %%
fruit_price

# %%
fruits = ('apple','cherry','dates')

# %%
len(fruits)

# %%
fruits[2]

# %%
"dates"  in fruits

# %%
fruits[0] = "avacado"

# %%
fruits.remove("apple")

# %%
the_3_musketeers = 'Athos','Porthos','Aramis'

# %%
type(the_3_musketeers)
# Out:
# tuple

# %%
akash = (4)

# %%
type(akash)
# Out:
# int

# %%
akash = 4,

# %%
type(akash)
# Out:
# tuple

# %%
akashGurkha = (4,)

# %%
type(akashGurkha)
# Out:
# tuple

# %%
point = (3,4)

# %%
point_x,point_y = point

# %%
point_x
# Out:
# 3

# %%
point_y
# Out:
# 4

# %%
tuple(["one","two","three"])
# Out:
# ('one', 'two', 'three')

# %%
list(("athos","porthos","aramis"))
# Out:
# ['athos', 'porthos', 'aramis']

# %%
a_tuple = 23,"hello",False,None,23,45

# %%
help(a_tuple.count)
# Out:
# Help on built-in function count:
#
# count(value, /) method of builtins.tuple instance
#     Return number of occurrences of value.

# %%
a_tuple.count(23)
# Out:
# 2

# %%
help(a_tuple.index)
# Out:
# Help on built-in function index:
#
# index(value, start=0, stop=9223372036854775807, /) method of builtins.tuple instance
#     Return first index of value.
#
#     Raises ValueError if the value is not present.

# %%
a_tuple.index(23)
# Out:
# 0

# %%
# ?a_tuple.index

# %%
person1 = {
    "name":"John Doe",
    "sex":"Male",
    "age":32,
    "married":True
}

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person2 = dict(name="Jane Judy",sex="Female",age=28,married=False)

# %%
person2
# Out:
# {'name': 'Jane Judy', 'sex': 'Female', 'age': 28, 'married': False}

# %%
type(person2)
# Out:
# dict

# %%
type(person1)
# Out:
# dict

# %%
person1["name"]
# Out:
# 'John Doe'

# %%
person2["name"]
# Out:
# 'Jane Judy'

# %%
person1['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-786906807.py in <cell line: 0>()
# ----> 1 person1['address']
#
# KeyError: 'address'

# %%
person1.get("address","unknown")
# Out:
# 'unknown'

# %%
'name' in person1
# Out:
# True

# %%
'address' in person1
# Out:
# False

# %%
person2['married'] = True

# %%
person2['married']
# Out:
# True

# %%
person1['address']='1,penny lane'

# %%
person1
# Out:
# {'name': 'John Doe',
#  'sex': 'Male',
#  'age': 32,
#  'married': True,
#  'address': '1,penny lane'}

# %%
person1.pop('address')
# Out:
# '1,penny lane'

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person1.keys()
# Out:
# dict_keys(['name', 'sex', 'age', 'married'])

# %%
person1.values()
# Out:
# dict_values(['John Doe', 'Male', 32, True])

# %%
person1.items()
# Out:
# dict_items([('name', 'John Doe'), ('sex', 'Male'), ('age', 32), ('married', True)])

# %%
person1.items()[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2295007945.py in <cell line: 0>()
# ----> 1 person1.items()[1]
#
# TypeError: 'dict_items' object is not subscriptable
